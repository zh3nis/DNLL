# %% [markdown]
# # Fashion-MNIST Classification with an MDA Head
# This notebook trains a small convolutional encoder with a mixture discriminant analysis (MDA) head
# on Fashion-MNIST, then evaluates calibration plots.

# %% [markdown]
# ### Setup

# %%
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from dnll import MDAHead, DNLLLoss

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
tfm = transforms.ToTensor()
train_ds = datasets.FashionMNIST(root='./data', train=True, transform=tfm, download=True)
test_ds  = datasets.FashionMNIST(root='./data', train=False, transform=tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=2, pin_memory=True)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %% [markdown]
# ### Model: encoder + MDA head

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(1),
        )
        self.proj = nn.Linear(256, dim)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.proj(x)

class DeepMDA(nn.Module):
    def __init__(self, C, D, K):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = MDAHead(C, D, K)

    def forward(self, x):
        z = self.encoder(x)
        return self.head(z)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot


model = DeepMDA(C=10, D=9, K=2).to(device)
opt = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = DNLLLoss(lambda_reg=1.0)

train_acc = []
test_acc = []

for epoch in range(1, 101):
    model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = loss_fn(logits, y)
        opt.zero_grad(set_to_none=True)
        loss.backward()
        opt.step()
        with torch.no_grad():
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)
    tr_acc = acc_sum / n_sum
    te_acc = evaluate(model, test_ld)
    train_acc.append(tr_acc)
    test_acc.append(te_acc)
    print(f'[MDA {epoch:02d}] train loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}')
# Out:
# [MDA 01] train loss=2.7997 acc=0.8034 | test acc=0.7676
# [MDA 02] train loss=1.7155 acc=0.8925 | test acc=0.8423
# [MDA 03] train loss=1.3313 acc=0.9141 | test acc=0.8887
# [MDA 04] train loss=1.2410 acc=0.9289 | test acc=0.9081
# [MDA 05] train loss=1.2092 acc=0.9371 | test acc=0.9204
# [MDA 06] train loss=1.1858 acc=0.9452 | test acc=0.9131
# [MDA 07] train loss=1.1642 acc=0.9526 | test acc=0.9143
# [MDA 08] train loss=1.1515 acc=0.9579 | test acc=0.8979
# [MDA 09] train loss=1.1340 acc=0.9639 | test acc=0.8889
# [MDA 10] train loss=1.1214 acc=0.9684 | test acc=0.9031
# [MDA 11] train loss=1.1052 acc=0.9746 | test acc=0.9198
# [MDA 12] train loss=1.0914 acc=0.9802 | test acc=0.9251
# [MDA 13] train loss=1.0779 acc=0.9846 | test acc=0.9268
# [MDA 14] train loss=1.0677 acc=0.9881 | test acc=0.9246
# [MDA 15] train loss=1.0616 acc=0.9899 | test acc=0.8762
# [MDA 16] train loss=1.0481 acc=0.9941 | test acc=0.9205
# [MDA 17] train loss=1.0422 acc=0.9955 | test acc=0.9081
# [MDA 18] train loss=1.0341 acc=0.9972 | test acc=0.8865
# [MDA 19] train loss=1.0373 acc=0.9961 | test acc=0.9245
# [MDA 20] train loss=1.0302 acc=0.9975 | test acc=0.9229
# [MDA 21] train loss=1.0227 acc=0.9992 | test acc=0.9289
# [MDA 22] train loss=1.0201 acc=0.9993 | test acc=0.9269
# [MDA 23] train loss=1.0234 acc=0.9987 | test acc=0.9282
# [MDA 24] train loss=1.0246 acc=0.9985 | test acc=0.9177
# [MDA 25] train loss=1.0203 acc=0.9992 | test acc=0.9290
# [MDA 26] train loss=1.0147 acc=0.9997 | test acc=0.9279
# [MDA 27] train loss=1.0172 acc=0.9990 | test acc=0.9021
# [MDA 28] train loss=1.0169 acc=0.9993 | test acc=0.9207
# [MDA 29] train loss=1.0224 acc=0.9982 | test acc=0.9213
# [MDA 30] train loss=1.0219 acc=0.9980 | test acc=0.9213
# [MDA 31] train loss=1.0265 acc=0.9970 | test acc=0.9117
# [MDA 32] train loss=1.0124 acc=0.9994 | test acc=0.9162
# [MDA 33] train loss=1.0052 acc=1.0000 | test acc=0.9284
# [MDA 34] train loss=1.0028 acc=1.0000 | test acc=0.9388
# [MDA 35] train loss=1.0020 acc=1.0000 | test acc=0.9387
# [MDA 36] train loss=1.0016 acc=1.0000 | test acc=0.9389
# [MDA 37] train loss=1.0016 acc=1.0000 | test acc=0.9399
# [MDA 38] train loss=1.0014 acc=1.0000 | test acc=0.9368
# [MDA 39] train loss=1.0013 acc=1.0000 | test acc=0.9343
# [MDA 40] train loss=1.0014 acc=1.0000 | test acc=0.9352
# [MDA 41] train loss=1.0017 acc=1.0000 | test acc=0.9347
# [MDA 42] train loss=1.0810 acc=0.9787 | test acc=0.9024
# [MDA 43] train loss=1.0487 acc=0.9889 | test acc=0.8803
# [MDA 44] train loss=1.0143 acc=0.9988 | test acc=0.9304
# [MDA 45] train loss=1.0077 acc=0.9997 | test acc=0.9305
# [MDA 46] train loss=1.0077 acc=0.9995 | test acc=0.9378
# [MDA 47] train loss=1.0026 acc=1.0000 | test acc=0.9381
# [MDA 48] train loss=1.0018 acc=1.0000 | test acc=0.9373
# [MDA 49] train loss=1.0014 acc=1.0000 | test acc=0.9380
# [MDA 50] train loss=1.0012 acc=1.0000 | test acc=0.9384
# [MDA 51] train loss=1.0011 acc=1.0000 | test acc=0.9379
# [MDA 52] train loss=1.0011 acc=1.0000 | test acc=0.9380
# [MDA 53] train loss=1.0010 acc=1.0000 | test acc=0.9369
# [MDA 54] train loss=1.0009 acc=1.0000 | test acc=0.9376
# [MDA 55] train loss=1.0010 acc=1.0000 | test acc=0.9365
# [MDA 56] train loss=1.0010 acc=1.0000 | test acc=0.9362
# [MDA 57] train loss=1.0659 acc=0.9823 | test acc=0.9090
# [MDA 58] train loss=1.0357 acc=0.9926 | test acc=0.9084
# [MDA 59] train loss=1.0102 acc=0.9991 | test acc=0.9310
# [MDA 60] train loss=1.0038 acc=1.0000 | test acc=0.9375
# [MDA 61] train loss=1.0020 acc=1.0000 | test acc=0.9393
# [MDA 62] train loss=1.0016 acc=1.0000 | test acc=0.9376
# [MDA 63] train loss=1.0012 acc=1.0000 | test acc=0.9378
# [MDA 64] train loss=1.0010 acc=1.0000 | test acc=0.9374
# [MDA 65] train loss=1.0009 acc=1.0000 | test acc=0.9380
# [MDA 66] train loss=1.0008 acc=1.0000 | test acc=0.9385
# [MDA 67] train loss=1.0008 acc=1.0000 | test acc=0.9385
# [MDA 68] train loss=1.0007 acc=1.0000 | test acc=0.9379
# [MDA 69] train loss=1.0007 acc=1.0000 | test acc=0.9387
# [MDA 70] train loss=1.0554 acc=0.9858 | test acc=0.9230
# [MDA 71] train loss=1.0163 acc=0.9978 | test acc=0.9261
# [MDA 72] train loss=1.0047 acc=0.9999 | test acc=0.9340
# [MDA 73] train loss=1.0020 acc=1.0000 | test acc=0.9353
# [MDA 74] train loss=1.0013 acc=1.0000 | test acc=0.9368
# [MDA 75] train loss=1.0012 acc=1.0000 | test acc=0.9369
# [MDA 76] train loss=1.0009 acc=1.0000 | test acc=0.9354
# [MDA 77] train loss=1.0009 acc=1.0000 | test acc=0.9346
# [MDA 78] train loss=1.0008 acc=1.0000 | test acc=0.9357
# [MDA 79] train loss=1.0007 acc=1.0000 | test acc=0.9357
# [MDA 80] train loss=1.0006 acc=1.0000 | test acc=0.9375
# [MDA 81] train loss=1.0006 acc=1.0000 | test acc=0.9370
# [MDA 82] train loss=1.0436 acc=0.9898 | test acc=0.9276
# [MDA 83] train loss=1.0184 acc=0.9967 | test acc=0.9225
# [MDA 84] train loss=1.0037 acc=1.0000 | test acc=0.9372
# [MDA 85] train loss=1.0018 acc=1.0000 | test acc=0.9367
# [MDA 86] train loss=1.0012 acc=1.0000 | test acc=0.9374
# [MDA 87] train loss=1.0009 acc=1.0000 | test acc=0.9375
# [MDA 88] train loss=1.0007 acc=1.0000 | test acc=0.9388
# [MDA 89] train loss=1.0007 acc=1.0000 | test acc=0.9383
# [MDA 90] train loss=1.0006 acc=1.0000 | test acc=0.9370
# [MDA 91] train loss=1.0006 acc=1.0000 | test acc=0.9382
# [MDA 92] train loss=1.0006 acc=1.0000 | test acc=0.9371
# [MDA 93] train loss=1.0006 acc=1.0000 | test acc=0.9379
# [MDA 94] train loss=1.0005 acc=1.0000 | test acc=0.9373
# [MDA 95] train loss=1.0005 acc=1.0000 | test acc=0.9375
# [MDA 96] train loss=1.0004 acc=1.0000 | test acc=0.9366
# [MDA 97] train loss=1.0004 acc=1.0000 | test acc=0.9367
# [MDA 98] train loss=1.0005 acc=1.0000 | test acc=0.9372
# [MDA 99] train loss=1.0004 acc=1.0000 | test acc=0.9371
# [MDA 100] train loss=1.0411 acc=0.9894 | test acc=0.8859

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_acc) + 1)
plt.figure(figsize=(6.5, 4.5))
plt.plot(epochs, train_acc, label='Train acc', linewidth=2)
plt.plot(epochs, test_acc, label='Test acc', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('MDA FashionMNIST Accuracy')
plt.legend(frameon=False)
plt.grid(True, linewidth=0.4, alpha=0.4)
plt.tight_layout()
plt.show()
